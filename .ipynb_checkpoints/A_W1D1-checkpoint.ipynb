# %%
import torch
import torchvision

# %%
torch.__version__
# Out:
# '2.5.1'

# %%
torchvision.__version__
# Out:
# '0.20.1'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.version.cuda
# Out:
# '12.4'

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce GTX 1050'
